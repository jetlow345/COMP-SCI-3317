# %% [markdown]
# # Workshop2

# %%
# load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load data
data = pd.read_csv("workshop2.csv")

# %%
# See data
data
# Out:
#        longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41         880           129.0
# 1        -122.22     37.86                  21        7099          1106.0
# 2        -122.24     37.85                  52        1467           190.0
# 3        -122.25     37.85                  52        1274           235.0
# 4        -122.25     37.85                  52        1627           280.0
# ...          ...       ...                 ...         ...             ...
# 20635    -121.09     39.48                  25        1665           374.0
# 20636    -121.21     39.49                  18         697           150.0
# 20637    -121.22     39.43                  17        2254           485.0
# 20638    -121.32     39.43                  18        1860           409.0
# 20639    -121.24     39.37                  16        2785           616.0
#
#        population  households  median_income  median_house_value  \
# ...

# %%
# Check first rows
data.tail()
# Out:
#        longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25        1665           374.0
# 20636    -121.21     39.49                  18         697           150.0
# 20637    -121.22     39.43                  17        2254           485.0
# 20638    -121.32     39.43                  18        1860           409.0
# 20639    -121.24     39.37                  16        2785           616.0
#
#        population  households  median_income  median_house_value  \
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
# Check description of data
data.describe()
# Out:
#           longitude      latitude  housing_median_age  total_bedrooms  \
# count  20640.000000  20640.000000        20640.000000    20433.000000
# mean    -119.569704     35.648344           28.656928      537.870553
# std        2.003532      3.200177           12.848021      421.385070
# min     -124.350000     32.540000            1.000000        1.000000
# 25%     -121.800000     33.930000           18.000000      296.000000
# 50%     -118.490000     34.260000           29.000000      435.000000
# 75%     -118.010000     37.710000           37.000000      647.000000
# max     -114.310000    378.000000          400.000000     6445.000000
#
#          population    households  median_income  median_house_value
# count  20640.000000  20640.000000   20640.000000        20640.000000
# mean    1425.379942    499.539680       3.870623       206855.816909
# std     1132.583966    382.329753       1.899920       115395.615874
# ...

# %%
# Check data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  object
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
# Remove a column 
data = data.drop('ocean_proximity',axis = 1)

# %%
# Convert column 'total_rooms' to numeric
data['total_rooms'] =  pd.to_numeric(data['total_rooms'],errors = 'coerce')

# %%
# Remove rows with nan values (missing values)
data = data.dropna()

# %%
# Plot one variable
plt.plot(data['total_rooms'],'o')

# %%
# Plot multiple variables
for col in data.columns:
    plt.plot(data[col],'o')
    plt.title(col)
    plt.show()

# %%
# Checking data, we identify a 'potential' wrong value of latitude, which value is over 350. We can check this sample.
data.loc[data['latitude'] > 350,:]
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 220    -122.21     378.0                  39       2003.0           500.0
#
#      population  households  median_income  median_house_value
# 220        1109         464         3.0682              156500

# %%
# We can replace this value for nan
data.loc[data['latitude'] > 350,'latitude'] = np.nan

# %%
# We can plot the vaiable latitude again and corroborate that value over 350 was removed
plt.plot(data['latitude'],'o')

# %%
# As we introduced a new nan value, we need to remove the entire row with the missing value
data = data.dropna()

# %%
# Using data describe we can check that our variables have the same number of correct values (checking the row 'count')
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  19425.000000  19425.000000        19425.000000  19425.000000
# mean    -119.571131     35.631981           28.669344   2641.977040
# std        2.002041      2.134439           12.867788   2195.582812
# min     -124.350000     32.550000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1452.000000
# 50%     -118.490000     34.260000           29.000000   2126.000000
# 75%     -118.010000     37.710000           37.000000   3144.000000
# max     -114.310000     41.950000          400.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    19425.000000  19425.000000  19425.000000   19425.000000
# mean       538.694723   1427.138121    500.223629       3.873155
# std        422.937281   1138.070761    383.422977       1.900384
# min          1.000000   -999.000000      1.000000      -0.499900
# ...

# %%
# Now we can split our data in y and X
y = data['median_house_value']
X = data.loc[:,'longitude':'median_income']

# %%
# Now, we can split our dataset in train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
# Now  we can implement a linear regression model 
from sklearn.linear_model import LinearRegression

# Create a model object
model = LinearRegression()
# Train a model
model.fit(X_train,y_train)

# We can do prediction in train set
model.predict(X_train)
# Out:
# array([161116.35173143,  75126.25308709, 196091.71852916, ...,
#        161834.19857706, 187677.99106532, 107300.5910385 ])

# %%
# We can do prediction in test set
model.predict(X_test)
# Out:
# array([374072.62619555, 137360.8154946 ,  80989.97263977, ...,
#        177477.77607196, 323636.51286589, 181493.3580892 ])
